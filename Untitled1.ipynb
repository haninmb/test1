# %%
# !mkdir /root/.kaggle
my_api = '{"username":"haninlibya","key":"d76dfd950b93fb2dc32034551fdbe7f2"}'
with open('/root/.kaggle/kaggle.json', 'w') as f:
    f.write(my_api)
    f.close()
# Out:
# The syntax of the command is incorrect.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16472\1210117530.py in <module>
#       1 get_ipython().system('mkdir /root/.kaggle')
#       2 my_api = '{"username":"haninlibya","key":"d76dfd950b93fb2dc32034551fdbe7f2"}'
# ----> 3 with open('/root/.kaggle/kaggle.json', 'w') as f:
#       4     f.write(my_api)
#       5     f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.kaggle/kaggle.json'

# %%
# !kaggle datasets download -d andrewmvd/animal-faces
# Out:
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip /content/animal-faces.zip

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
path = '/content/afhq/train'

# %%
tf.keras.preprocessing.image.load_img('/content/afhq/train/cat/flickr_cat_000013.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7FD347A7BA30>
